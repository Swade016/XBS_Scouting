# %%
import pandas as pd
import numpy as np
from XBS import XBS
from Config import Config
from Config import Positions
from bs4 import BeautifulSoup
from Game import Game

# %%
xbs = XBS()

# %%
game = Game(4561)

# %%
html = game.Soup.find_all('table')

# %%
print(len(list(html)))
for index, tag in enumerate(html):
    print('\n Index = %d - Tag Length = %d \n' % (index, len(list(tag))))
    print(tag)

# %%
threestar = html[21]

# print(type(threestar))
# print(threestar.name)
# print(len(threestar.contents))
# print(threestar.contents)
print('\n')

for x in threestar:
    try:
        print('%s - \n%s\n' % (type(x), x.contents))
        print(x.get_text())
    except AttributeError:
        print('skipping')
        print(AttributeError)
        print('\n')
        continue
    

# for index, x in enumerate(threestar.contents):
#     print('Index %d\nType %s\nContent %s\n' % (index, type(x), x))

# if(len(list(threestar))) > 3:
#     text = threestar.get_text().strip()
    
#     for index, x in enumerate(text):
#         print('%d - %s' % (len(x), x))
    
# x = []

# for index, tag in enumerate(threestar):
#     print('\n Index = %d - Tag Length = %d \n' % (index, len(list(tag))))
#     print(tag.get_text())    
# print(threestar)
# Out:
# skipping
# <class 'AttributeError'>
#
#
# <class 'bs4.element.Tag'> -
# ['\n', <td align="center" class="xbshl-table-header">Three Stars of the Game</td>, '\n']
#
#
# Three Stars of the Game
#
# skipping
# <class 'AttributeError'>
#
#
# <class 'bs4.element.Tag'> -
# ['\n', <td style="padding-top:8px;padding-bottom:8px;"><strong class="color_1a">Game Leaders</strong></td>, '\n']
#
#
# Game Leaders
#
# skipping
# <class 'AttributeError'>
#
#
# <class 'bs4.element.Tag'> -
# ['\n', <td class="xbs-border" style="padding:0px;"></td>, '\n']
#
#
#
#
# skipping
# <class 'AttributeError'>
#
#
# <class 'bs4.element.Tag'> -
# ['\n', <td align="center" class="">
# <div style="width:45px;height:45px;border:1px solid #d0d0d0;float:left;margin-right:10px;">
# <div style="width:45px;height:45px;overflow:hidden;">
# <img alt="" height="150" src="https://avatar-ssl.xboxlive.com/avatar/pixeliscool/avatar-body.png" style="margin-left: -16px;margin-top: -23px;" width="75"/>
# </div>
# </div>
# ...

# %%
xbs.Roster.GetAllPlayers()
wade = xbs.Roster.FindByID(2270)
print(wade)
wade.GetSeasonStats()
wade.SeasonStats.Stats
